# %%
# обработка данных
import pandas as pd
import numpy as np
from datetime import datetime

# сетап plot.ly - режим работы в тетрадке и импорт объектов
from plotly.offline import init_notebook_mode, plot, iplot
from plotly import graph_objs as go
init_notebook_mode(connected=True)

# задачи машинного обучения
from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
from sklearn.model_selection import GridSearchCV, cross_val_score, cross_val_predict, ParameterGrid
from sklearn import metrics

# прочее
import warnings
warnings.filterwarnings('ignore')
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %% [markdown]
# Загрузим данные для работы в датафрейм. Маленький фокус для правильной работы - функция для парсинга даты.

# %%
def date_parser(string):
    date = datetime.strptime(string, '%d.%m.%Y')
    return date

df = pd.read_csv('Тестовое задание.csv',
                 sep=';',
                 parse_dates=[0],
                 index_col=0,
                 date_parser=date_parser,
                 engine='python',
                 encoding='utf-8')

df.head()
# Out:
#             Продажи упаковки  Россия 1  Домашний  НТВ  Первый Канал  \
# Неделя
# 2010-01-04            7092.0         0         0    0             0
# 2010-01-11            8664.0         0         0    0             0
# 2010-01-18            7526.0         0         0    0             0
# 2010-01-25            9165.0         0         0    0             0
# 2010-02-01            8713.0         0         0    0             0
#
#             Пятый Канал  ТВ Центр  ТВ-3  Рен ТВ  Звезда  Нишевые каналы  \
# Неделя
# 2010-01-04            0         0     0       0       0               0
# 2010-01-11            0         0     0       0       0               0
# 2010-01-18            0         0     0       0       0               0
# 2010-01-25            0         0     0       0       0               0
# 2010-02-01            0         0     0       0       0               0
#
#             Реклама в прессе  Конкурент1  Конкурент2  Конкурент3  Конкурент4  \
# Неделя
# 2010-01-04                 0           0           0           0           0
# 2010-01-11                 0           0           0           0           0
# 2010-01-18                50           0           0           0           0
# 2010-01-25                56           0           0           0           0
# 2010-02-01                 6           0           0           0           0
#
#             Цена бренда  Средняя цена в категории
# Неделя
# 2010-01-04           55                       104
# 2010-01-11           52                       100
# 2010-01-18           53                        97
# 2010-01-25           55                       103
# 2010-02-01           52                       101

# %%
def plotly_df(df, title = ''):
    '''
    Наивная рисовалка графиков из датафрейма
    '''
    data = []
    
    for column in df.columns:
        trace = go.Scatter(x=df.index,
                          y=df[column],
                          mode='lines',
                          name=column)
        data.append(trace)
        
    layout = dict(title=title)
    fig = dict(data = data, layout = layout)
    iplot(fig, show_link=False)

# %%
sales = df[['Продажи упаковки']]
sales = sales[sales['Продажи упаковки'] > 0]
plotly_df(sales, title='Продажи')
# Out:
# <div id="13b4e7c9-918f-46c9-9cdc-69d8c0732c6a" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("13b4e7c9-918f-46c9-9cdc-69d8c0732c6a", [{"type": "scatter", "x": ["2010-01-04", "2010-01-11", "2010-01-18", "2010-01-25", "2010-02-01", "2010-02-08", "2010-02-15", "2010-02-22", "2010-03-01", "2010-03-08", "2010-03-15", "2010-03-22", "2010-03-29", "2010-04-05", "2010-04-12", "2010-04-19", "2010-04-26", "2010-05-03", "2010-05-10", "2010-05-17", "2010-05-24", "2010-05-31", "2010-06-07", "2010-06-14", "2010-06-21", "2010-06-28", "2010-07-05", "2010-07-12", "2010-07-19",
 13169.0, 10968.0, 10250.0, 10231.0, 9699.0, 10098.0, 9514.0, 8393.0, 7421.0, 9789.0, 8604.0, 7991.0, 8143.0, 8850.0, 9439.0, 8848.0, 9550.0, 10675.0, 10382.0, 9974.0, 9294.0, 9105.0, 9135.0, 9503.0, 8983.0, 8887.0, 8568.0, 8056.0, 8001.0, 8606.0, 9226.0, 9696.0, 8401.0, 8649.0, 8140.0, 8654.0, 8530.0, 8032.0, 8118.0, 8985.0, 7780.0, 7908.0], "mode": "lines", "name": "\u041f\u0440\u043e\u0434\u0430\u0436\u0438 \u0443\u043f\u0430\u043a\u043e\u0432\u043a\u0438"}], {"title": "\u ...

# %% [markdown]
# Из графика хорошо видно, что временной ряд не является стационарным, т.к.:
#     - большой разброс значений
#     - значения становятся ближе друг к другу
#
# Поэтому мы не будем использовать ARMA-based модели, и имеет смысл рассматривать скользящее среднее, взвешенное среднее, экпоненциальное сглаживание и двойное экспоненциальное сглаживание, при рассмотре данных как временного ряда для анализа ближайших трендов и использовать регрессию для построения прогнозов.

# %%
df.describe()
# Out:
#        Продажи упаковки    Россия 1    Домашний         НТВ  Первый Канал  \
# count        156.000000  195.000000  195.000000  195.000000    195.000000
# mean       10028.660256   12.569231    1.830769    1.451282      6.328205
# std         2071.714208   21.652101    4.125240    7.189012     17.396379
# min         6077.000000    0.000000    0.000000    0.000000      0.000000
# 25%         8399.000000    0.000000    0.000000    0.000000      0.000000
# 50%         9744.000000    0.000000    0.000000    0.000000      0.000000
# 75%        11290.000000   36.000000    0.000000    0.000000      0.000000
# max        15715.000000  100.000000   22.000000   50.000000     74.000000
#
#        Пятый Канал    ТВ Центр        ТВ-3      Рен ТВ      Звезда  \
# count   195.000000  195.000000  195.000000  195.000000  195.000000
# mean      1.158974    0.671795    0.400000    0.225641    0.292308
# std       4.694849    2.748003    1.972491    1.624668    1.468463
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       0.000000    0.000000    0.000000    0.000000    0.000000
# 50%       0.000000    0.000000    0.000000    0.000000    0.000000
# 75%       0.000000    0.000000    0.000000    0.000000    0.000000
# max      29.000000   18.000000   12.000000   15.000000    9.000000
#
#        Нишевые каналы  Реклама в прессе  Конкурент1  Конкурент2  Конкурент3  \
# count      195.000000        195.000000  195.000000  195.000000  195.000000
# mean         0.912821         11.276923    4.866667    2.989744    3.502564
# std          3.237600         19.666687   13.373411    6.145143    9.043637
# min          0.000000          0.000000    0.000000    0.000000    0.000000
# 25%          0.000000          0.000000    0.000000    0.000000    0.000000
# 50%          0.000000          0.000000    0.000000    0.000000    0.000000
# 75%          0.000000         15.000000    0.000000    0.000000    0.000000
# max         20.000000        100.000000   77.000000   22.000000   62.000000
#
#        Конкурент4  Цена бренда  Средняя цена в категории
# count  195.000000   195.000000                195.000000
# mean     2.635897    79.333333                130.230769
# std      5.212568    14.878431                 16.511261
# min      0.000000    52.000000                 97.000000
# 25%      0.000000    68.000000                117.000000
# 50%      0.000000    80.000000                133.000000
 9105.0, 9135.0, 9503.0, 8983.0, 8887.0, 8568.0, 8056.0, 8001.0, 8606.0, 9226.0, 9696.0, 8401.0, 8649.0, 8140.0, 8654.0, 8530.0, 8032.0, 8118.0, 8985.0, 7780.0, 7908.0], "mode": "lines", "name": "\u041f\u0440\u043e\u0434\u0430\u0436\u0438 \u0443\u043f\u0430\u043a\u043e\u0432\u043a\u0438"}, {"type": "scat ...

# %% [markdown]
# Примечание - если на легенде нажать на линию, она изчезнет, можно сравнивать меньшее количество графиков.

# %% [markdown]
# В качестве модели будем использовать линейную регрессию, добавив некоторые дополнительные признаки - неделю, значение продаж неделю, месяц, квартал назад. Для выбора лучшей модели воспользуемся классом GridSearchCV, который принимает на вход изменяемые параметры для модели и отдает на выход оптимальные параметры.
#
# В качестве метрики будем использовать r2_score, т.к. эта метрика позволяет оценить качество модели для прогнозов.
#
# Больших лагов добавлять не будем, т.к. теряется очень большая часть выборки.

# %%
data['Неделя'] = data.index.week
learning_samples = data.copy()

for i in range(4, 13):
    learning_samples[f'Lag {i}'] = learning_samples['Продажи упаковки'].shift(i)

learning_samples = learning_samples.dropna()
learning_samples.head()
# Out:
#             Продажи упаковки  Россия 1  Домашний  НТВ  Первый Канал  \
# Неделя
# 2010-03-29            7389.0         0         0    0             0
# 2010-04-05            8215.0         0         0    0             0
# 2010-04-12            8121.0         0         0    0             0
# 2010-04-19            8120.0         0         0    0             0
# 2010-04-26            7494.0         0         0    0             0
#
#             Пятый Канал  ТВ Центр  ТВ-3  Рен ТВ  Звезда   ...    Неделя  \
# Неделя                                                    ...
# 2010-03-29            0         0     0       0       0   ...        13
# 2010-04-05            0         0     0       0       0   ...        14
# 2010-04-12            0         0     0       0       0   ...        15
# 2010-04-19            0         0     0       0       0   ...        16
# 2010-04-26            0         0     0       0       0   ...        17
#
#              Lag 4   Lag 5   Lag 6   Lag 7   Lag 8   Lag 9  Lag 10  Lag 11  \
# Неделя
# 2010-03-29  9154.0  7798.0  8595.0  7489.0  8713.0  9165.0  7526.0  8664.0
# 2010-04-05  8317.0  9154.0  7798.0  8595.0  7489.0  8713.0  9165.0  7526.0
# 2010-04-12  8671.0  8317.0  9154.0  7798.0  8595.0  7489.0  8713.0  9165.0
# 2010-04-19  8837.0  8671.0  8317.0  9154.0  7798.0  8595.0  7489.0  8713.0
# 2010-04-26  7389.0  8837.0  8671.0  8317.0  9154.0  7798.0  8595.0  7489.0
#
#             Lag 12
# Неделя
# 2010-03-29  7092.0
# 2010-04-05  8664.0
# 2010-04-12  7526.0
# 2010-04-19  9165.0
# 2010-04-26  8713.0
#
# [5 rows x 28 columns]

# %%
learning_samples.tail()
# Out:
#             Продажи упаковки  Россия 1  Домашний  НТВ  Первый Канал  \
# Неделя
# 2012-11-26            8032.0         0         0    0             0
# 2012-12-03            8118.0         0         0    0             0
# 2012-12-10            8985.0        40         0    0             0
# 2012-12-17            7780.0        58         0    0             0
# 2012-12-24            7908.0         0         0    0             0
#
#             Пятый Канал  ТВ Центр  ТВ-3  Рен ТВ  Звезда   ...    Неделя  \
# Неделя                                                    ...
# 2012-11-26           13         9     0       0       0   ...        48
# 2012-12-03           16         9     0       0       0   ...        49
# 2012-12-10            0         0     0       0       0   ...        50
# 2012-12-17            0         0     0       0       0   ...        51
# 2012-12-24            0         0     0       0       0   ...        52
#
#              Lag 4   Lag 5   Lag 6   Lag 7   Lag 8   Lag 9  Lag 10  Lag 11  \
# Неделя
# 2012-11-26  8649.0  8401.0  9696.0  9226.0  8606.0  8001.0  8056.0  8568.0
# 2012-12-03  8140.0  8649.0  8401.0  9696.0  9226.0  8606.0  8001.0  8056.0
# 2012-12-10  8654.0  8140.0  8649.0  8401.0  9696.0  9226.0  8606.0  8001.0
# 2012-12-17  8530.0  8654.0  8140.0  8649.0  8401.0  9696.0  9226.0  8606.0
# 2012-12-24  8032.0  8530.0  8654.0  8140.0  8649.0  8401.0  9696.0  9226.0
#
#             Lag 12
# Неделя
# 2012-11-26  8887.0
# 2012-12-03  8568.0
# 2012-12-10  8056.0
# 2012-12-17  8001.0
# 2012-12-24  8606.0
#
# [5 rows x 28 columns]

# %%
len(learning_samples)
# Out:
# 144

# %%
X_train = learning_samples[:116].drop('Продажи упаковки', axis=1)
y_train = learning_samples[:116]['Продажи упаковки']
X_test = learning_samples[116:].drop('Продажи упаковки', axis=1)
y_test = learning_samples[116:]['Продажи упаковки']

# %%
lin = LinearRegression()
lin.fit(X_train, y_train)

lin_predict = lin.predict(X_test)

# %%
plotly_df(pd.DataFrame({'Исходные данные': y_test, 'Прогноз': lin_predict}, index=learning_samples.index[116:]),
          title='Линейная регрессия без регуляризации')
# Out:
# <div id="92a51a52-0972-4ce8-a949-78d56433d208" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("92a51a52-0972-4ce8-a949-78d56433d208", [{"type": "scatter", "x": ["2012-06-18", "2012-06-25", "2012-07-02", "2012-07-09", "2012-07-16", "2012-07-23", "2012-07-30", "2012-08-06", "2012-08-13", "2012-08-20", "2012-08-27", "2012-09-03", "2012-09-10", "2012-09-17", "2012-09-24", "2012-10-01", "2012-10-08", "2012-10-15", "2012-10-22", "2012-10-29", "2012-11-05", "2012-11-12", "2012-11-19", "2012-11-26", "2012-12-03", "2012-12-10", "2012-12-17", "2012-12-24"], "y": [9439.0, 8848.0, 9550.0, 10675.0, 10382.0, 9974.0, 9294.0, 9105.0, 9135.0, 9503.0, 8983.0, 8887.0, 8568.0, 8056.0, 8001.0, 8606.0, 9226.0, 9696.0, 8401.0, 8649.0, 8140.0, 8654.0, 8530.0, 8032.0, 8118.0, 8985.0, 7780.0, 7908.0], "mode": "lines", "name": "\u0418\u0441\u0445\u043e\u0434\u043d\u044b\u0435 \u0434\u0430\u043d\u043d\u044b\u0435"}, {"type": "scatter", "x": ["2012-06-18", "2012-06-25", "2012-07-02", "2012-07-09", "2012-07-16", "2012-07-23", "2012-07-30", "2012-08-06", "2012-08-13", "2012-08-20", "2012-08-27", "2012-09-03", "2012-09-10", "2012-09-17", "2012-09-24", "2012-10-01", "2012-10-08", "2012-10-15", "2012-10-22", "2012-10-29", "2012-11-05", "2012-11-12", "2012-11-19", "2012-11-26", "2012-12-03", "2012-12-10", "2012-12-17", "2012-12-24"], "y": [8667.668063997606, 8192.125094600455, 8767.329021475267, 9021.244407237073, 9358.530265988316, 9248.672793462392, 8483.037045539873, -334.4976488419379, -902.4325449988701, 9111.582535973446, 8824.425132699655, 8947.03097310644, 8963.157000683834, 9898.176571758897, 9725.722917989124, 9351.65759815937, 9336.580442094886, 9074.636375744854, 8113.061216814396, 7212.529353992762, 6994.129805580204, 9345.968250207476, 8912.905242812763, 6986.370510727063, 6676.610686952584, 9421.326321671648, 9892.52317220954, 8313.375560851304], "mode": "lines", "name": "\u041f\u0440\u043e\u0433\u043d\u043e\u0437"}], {"title": "\u041b\u0438\u043d\u0435\u0439\u043d\u0430\u044f \u0440\u0435\u0433\u0440\u0435\u0441\u0441\u0438\u044f \u0431\u0435\u0437 \u0440\u0435\u0433\u0443\u043b\u044f\u0440\u0438\u0437\u0430\u0446\u0438\u0438"}, {"showLink": false, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# На графике видно, что модель неплохо обучилась, но случаются выбросы. Попробуем добавить регуляризацию.

# %%
param_grid = {'alpha': [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30, 100],
              'solver': ['sag', 'lsqr']}

ridge = Ridge()
ridge_cv = GridSearchCV(ridge,
                     param_grid=param_grid)
ridge_cv.fit(X_train, y_train)
ridge_predict = ridge_cv.predict(X_test)

plotly_df(pd.DataFrame({'Исходные данные': y_test, 'Прогноз': ridge_predict}, index=learning_samples.index[116:]),
          title=f'Ridge')
# Out:
# <div id="27ea73a6-d05c-4d9f-b0ad-48f3c2a4e911" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("27ea73a6-d05c-4d9f-b0ad-48f3c2a4e911", [{"type": "scatter", "x": ["2012-06-18", "2012-06-25", "2012-07-02", "2012-07-09", "2012-07-16", "2012-07-23", "2012-07-30", "2012-08-06", "2012-08-13", "2012-08-20", "2012-08-27", "2012-09-03", "2012-09-10", "2012-09-17", "2012-09-24", "2012-10-01", "2012-10-08", "2012-10-15", "2012-10-22", "2012-10-29", "2012-11-05", "2012-11-12", "2012-11-19", "2012-11-26", "2012-12-03", "2012-12-10", "2012-12-17", "2012-12-24"], "y": [9439.0, 8848.0, 9550.0, 10675.0, 10382.0, 9974.0, 9294.0, 9105.0, 9135.0, 9503.0, 8983.0, 8887.0, 8568.0, 8056.0, 8001.0, 8606.0, 9226.0, 9696.0, 8401.0, 8649.0, 8140.0, 8654.0, 8530.0, 8032.0, 8118.0, 8985.0, 7780.0, 7908.0], "mode": "lines", "name": "\u0418\u0441\u0445\u043e\u0434\u043d\u044b\u0435 \u0434\u0430\u043d\u043d\u044b\u0435"}, {"type": "scatter", "x": ["2012-06-18", "2012-06-25", "2012-07-02", "2012-07-09", "2012-07-16", "2012-07-23", "2012-07-30", "2012-08-06", "2012-08-13", "2012-08-20", "2012-08-27", "2012-09-03", "2012-09-10", "2012-09-17", "2012-09-24", "2012-10-01", "2012-10-08", "2012-10-15", "2012-10-22", "2012-10-29", "2012-11-05", "2012-11-12", "2012-11-19", "2012-11-26", "2012-12-03", "2012-12-10", "2012-12-17", "2012-12-24"], "y": [9139.509835967376, 8708.763401885371, 9377.91363205791, 9496.485767596922, 10032.092736539831, 10271.406512561887, 9327.993999060836, 9238.446552040132, 9734.441325879272, 9777.524471455828, 9567.970604098953, 9286.720293254606, 9296.658794692707, 9667.189924851165, 9538.449532116223, 9044.510674294288, 9945.507332045054, 9651.640724361516, 8281.58909940947, 8483.067652002888, 8856.190287318757, 10093.769674959955, 9787.05726091601, 8672.51852314754, 8631.025499132451, 10000.45758882436, 10611.286838037686, 8872.808289641709], "mode": "lines", "name": "\u041f\u0440\u043e\u0433\u043d\u043e\u0437"}], {"title": "Ridge"}, {"showLink": false, "linkText": "Export to plot.ly"})});</script>

# %%
for param, value in ridge_cv.best_params_.items():
    print(f'{param}: {value}')
    
print(f'R2 score: {metrics.r2_score(y_test, ridge_predict)}')
# Out:
# alpha: 100
# solver: lsqr
# R2 score: -0.5843955138314172

# %% [markdown]
# Видно, что модель сильно регуляризуется кросс-валидацией, посмотрим, как она ведет себя на остальном временном ряде. Кстати, напишем функцию для прогноза - на вход будем подавать ей обученную модель и исходные данные для прогноза, и будем в процессе выполнения функции извлекать лаги.

# %%
param_grid = {'alpha': [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30, 100]}

lasso = Lasso()
lasso_cv = GridSearchCV(lasso,
                     param_grid=param_grid)
lasso_cv.fit(X_train, y_train)
lasso_predict = lasso_cv.predict(X_test)

plotly_df(pd.DataFrame({'Исходные данные': y_test, 'Прогноз': lasso_predict}, index=learning_samples.index[116:]),
          title=f'Lasso')
# Out:
# <div id="6c5566ad-3fcf-4042-b069-70778f76f90b" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("6c5566ad-3fcf-4042-b069-70778f76f90b", [{"type": "scatter", "x": ["2012-06-18", "2012-06-25", "2012-07-02", "2012-07-09", "2012-07-16", "2012-07-23", "2012-07-30", "2012-08-06", "2012-08-13", "2012-08-20", "2012-08-27", "2012-09-03", "2012-09-10", "2012-09-17", "2012-09-24", "2012-10-01", "2012-10-08", "2012-10-15", "2012-10-22", "2012-10-29", "2012-11-05", "2012-11-12", "2012-11-19", "2012-11-26", "2012-12-03", "2012-12-10", "2012-12-17", "2012-12-24"], "y": [9439.0, 8848.0, 9550.0, 10675.0, 10382.0, 9974.0, 9294.0, 9105.0, 9135.0, 9503.0, 8983.0, 8887.0, 8568.0, 8056.0, 8001.0, 8606.0, 9226.0, 9696.0, 8401.0, 8649.0, 8140.0, 8654.0, 8530.0, 8032.0, 8118.0, 8985.0, 7780.0, 7908.0], "mode": "lines", "name": "\u0418\u0441\u0445\u043e\u0434\u043d\u044b\u0435 \u0434\u0430\u043d\u043d\u044b\u0435"}, {"type": "scatter", "x": ["2012-06-18", "2012-06-25", "2012-07-02", "2012-07-09", "2012-07-16", "2012-07-23", "2012-07-30", "2012-08-06", "2012-08-13", "2012-08-20", "2012-08-27", "2012-09-03", "2012-09-10", "2012-09-17", "2012-09-24", "2012-10-01", "2012-10-08", "2012-10-15", "2012-10-22", "2012-10-29", "2012-11-05", "2012-11-12", "2012-11-19", "2012-11-26", "2012-12-03", "2012-12-10", "2012-12-17", "2012-12-24"], "y": [8619.694510372135, 8111.480128864661, 8949.213632804045, 9190.809688883424, 9317.881809269273, 9249.686737931479, 8484.608750586403, 8585.340321386855, 9344.13426106182, 9098.68612007731, 8850.89979632751, 8991.36817561538, 8997.438582202667, 9883.873081192109, 9694.82965780642, 9305.142087970384, 9390.82487895348, 9124.804624191707, 8171.357847411429, 7255.2968868229445, 7377.858712950563, 9379.190429956487, 9010.744368366391, 7198.470826802536, 7118.192819929486, 9441.948851525696, 9940.70422806188, 8338.107979349053], "mode": "lines", "name": "\u041f\u0440\u043e\u0433\u043d\u043e\u0437"}], {"title": "Lasso"}, {"showLink": false, "linkText": "Export to plot.ly"})});</script>

# %% [markdown]
# sklearn настаивает на большей регуляризации и увеличении alpha. Посмотрим подобранные значения.

# %%
for param, value in lasso_cv.best_params_.items():
    print(f'{param}: {value}')
    
print(f'R2 score: {metrics.r2_score(y_test, lasso_predict)}')
# Out:
# alpha: 100
# R2 score: -0.5954442758819163

# %% [markdown]
# Повторим процедуру для elastic net

# %%
param_grid = {'alpha': [0.01, 0.03, 0.1, 0.3, 1, 3, 10, 30, 100],
              'l1_ratio': [0, 0.01, 0.03, 0.1, 0.3]}

elastic_net = ElasticNet()
elastic_net_cv = GridSearchCV(elastic_net,
                     param_grid=param_grid)
elastic_net_cv.fit(X_train, y_train)
elastic_net_predict = elastic_net_cv.predict(X_test)

plotly_df(pd.DataFrame({'Исходные данные': y_test, 'Прогноз': elastic_net_predict}, index=learning_samples.index[116:]),
          title='Elastic Net')
# Out:
# <div id="c6776a38-8def-431f-9b45-976f3c1293d1" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("c6776a38-8def-431f-9b45-976f3c1293d1", [{"type": "scatter", "x": ["2012-06-18", "2012-06-25", "2012-07-02", "2012-07-09", "2012-07-16", "2012-07-23", "2012-07-30", "2012-08-06", "2012-08-13", "2012-08-20", "2012-08-27", "2012-09-03", "2012-09-10", "2012-09-17", "2012-09-24", "2012-10-01", "2012-10-08", "2012-10-15", "2012-10-22", "2012-10-29", "2012-11-05", "2012-11-12", "2012-11-19", "2012-11-26", "2012-12-03", "2012-12-10", "2012-12-17", "2012-12-24"], "y": [9439.0, 8848.0, 9550.0, 10675.0, 10382.0, 9974.0, 9294.0, 9105.0, 9135.0, 9503.0, 8983.0, 8887.0, 8568.0, 8056.0, 8001.0, 8606.0, 9226.0, 9696.0, 8401.0, 8649.0, 8140.0, 8654.0, 8530.0, 8032.0, 8118.0, 8985.0, 7780.0, 7908.0], "mode": "lines", "name": "\u0418\u0441\u0445\u043e\u0434\u043d\u044b\u0435 \u0434\u0430\u043d\u043d\u044b\u0435"}, {"type": "scatter", "x": ["2012-06-18", "2012-06-25", "2012-07-02", "2012-07-09", "2012-07-16", "2012-07-23", "2012-07-30", "2012-08-06", "2012-08-13", "2012-08-20", "2012-08-27", "2012-09-03", "2012-09-10", "2012-09-17", "2012-09-24", "2012-10-01", "2012-10-08", "2012-10-15", "2012-10-22", "2012-10-29", "2012-11-05", "2012-11-12", "2012-11-19", "2012-11-26", "2012-12-03", "2012-12-10", "2012-12-17", "2012-12-24"], "y": [8985.598456419935, 8498.918839579796, 9155.970329149326, 9306.466770042658, 9546.062951077085, 9650.781421559892, 9040.81836030734, 9198.921060188844, 9837.230273185703, 9663.755986274744, 9402.135421848088, 9506.200459363687, 9389.610298940725, 9933.776738531218, 9437.717784694889, 9143.852697532882, 9668.367385737043, 9365.030186425722, 8373.424943034117, 8323.992585810049, 8626.409305507688, 9604.647864628743, 9248.393611879652, 8399.598942522354, 8384.626969612069, 9532.618561730253, 10006.852018038562, 8626.82118815038], "mode": "lines", "name": "\u041f\u0440\u043e\u0433\u043d\u043e\u0437"}], {"title": "Elastic Net"}, {"showLink": false, "linkText": "Export to plot.ly"})});</script>

# %%
for param, value in elastic_net_cv.best_params_.items():
    print(f'{param}: {value}')
print(f'R2 score: {metrics.r2_score(y_test, elastic_net_predict)}')
# Out:
# alpha: 100
# l1_ratio: 0
# R2 score: -0.2614545934838919

# %% [markdown]
# Из результатов видно, что лучший результат на тестовой выборке показала elastic_net. Будем использовать эту модель для прогноза.

# %%
def forecast(num_casts, model, dataframe):
    df = dataframe.copy()
    index = df.index
    pred_start = len(df) - num_casts
    for x in range(num_casts):
        # обновим лаги
        for i in range(4, 13):
            df.set_value(index[pred_start + x], f'Lag {i}', df.iloc[x - num_casts - i]['Продажи упаковки'])
        # получим предикт
        X = df.iloc[x - num_casts][1:]
        df.set_value(index[pred_start + x], 'Продажи упаковки', model.predict(X))
    return df

# %%
for i in range(4, 13):
    data[f'Lag {i}'] = data['Продажи упаковки'].shift(i)
    
results = forecast(39, elastic_net_cv, data)

# %%
def plot_results():
    data = []
    fcast = go.Scatter(y=results['Продажи упаковки'][-39:],
                       x=results['Продажи упаковки'][-39:].index,
                       name='Прогноз')
    data.append(fcast)
    
    start_data = go.Scatter(x=sales.index,
                            y=sales['Продажи упаковки'],
                            name='Исходные данные')
    data.append(start_data)
    fig = dict(data=data, layout={'title': 'Прогноз'})
    iplot(fig, show_link=False)

# %%
plot_results()
# Out:
# <div id="dc30af2a-427c-4f4a-9065-c3fa9c6136ed" style="height: 525px; width: 100%;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("dc30af2a-427c-4f4a-9065-c3fa9c6136ed", [{"type": "scatter", "y": [7858.334008192513, 8832.102241642504, 9671.753426294974, 8927.246255531572, 7913.946200913899, 8926.671336486208, 9279.76649139472, 8714.144409438037, 8112.116430993681, 7882.448645333148, 9389.708085339913, 9636.532078919145, 8442.544161667387, 8036.69353483026, 9163.98300031161, 9784.717540774931, 8785.19921579748, 8105.067999508892, 8239.965996762625, 8890.815063851558, 8990.692191952818, 9263.305253552127, 8885.22790994565, 8390.2053718039, 8861.34465100049, 9018.73404744552, 8658.264300577832, 8279.3007878573, 8491.36399568319, 8864.240114775064, 8861.44816047727, 8542.676425377624, 8462.843279033912, 8585.15713337856, 8750.928398037724, 8720.858517642873, 8497.498036759387, 8505.233632331432, 10192.391185396355], "x": ["2012-12-31", "2013-01-07", "2013-01-14", "2013-01-21", "2013-01-28", "2013-02-04", "2013-02-11", "2013-02-18", "2013-02-25", "2013-03-04", "2013-03-11", "2013-03-18", "2013-03-25", "2013-04-01", "2013-04-08", "2013-04-15", "2013-04-22", "2013-04-29", "2013-05-06", "2013-05-13", "2013-05-20", "2013-05-27", "2013-06-03", "2013-06-10", "2013-06-17", "2013-06-24", "2013-07-01", "2013-07-08", "2013-07-15", "2013-07-22